# %% [markdown]
# # Big Data in Finance: Part II <BR><BR> Lecture Notes 9: Compustat
#
# **Instructor** <BR>
# Lira Mota, lmota20@gsb.columbia.edu
#
# **TA's:** <BR>
# Meha Sadasivam, MSadasivam21@gsb.columbia.edu <BR>
# Daheng Yang, dyang22@gsb.columbia.edu

# %% [markdown]
# # Compustat
#
# In this section we are going to:
# 1. Download a set of US firm's annual fundamentals;
# 2. Understand how the data is organized:
#     1. Primary keys;
#     2. Secondary keys;
#     3. Data frequency;
#     4. Others.
# 2. Clean the data;
# 3. Construct important variables:
#     1. Book Equity Value
#     2. Asset Growth
#     3. Operational Profitability

# %% [markdown]
# ## How is the fundamentals data organized?
#
# * We can display all tables in "compm" library.
# * We are going to focus on the "funda" table: annual fundamentals.
# * Others that are interesting to know: "namesd"

# %% [markdown]
# ## Set Up

# %%
# %matplotlib inline 

#%% Packages 
import wrds
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 6]

import time
from time import strptime, strftime

# Setups
pd.set_option("display.max_rows", 200) # max number or rows to be displayed

# %%
#%% Set WRDS Connection
db = wrds.Connection(wrds_username='khardnett') # make sure to configure wrds connector before hand.
# Out:
# Loading library list...
# Done

# %% [markdown]
# ### All tables in compm

# %%
compm_tables = db.list_tables(library="comp") # compd: Compustat daily update

# %%
 pd.DataFrame({'tables':compm_tables}).head(100) # Transform libs to a Pandas data frame to have a better display.
# Out:
#              tables
# 0          aco_amda
# 1          aco_imda
# 2       aco_indfnta
# 3       aco_indfntq
# 4     aco_indfntytd
# 5        aco_indsta
# 6        aco_indstq
# 7      aco_indstytd
# 8        aco_notesa
# 9        aco_notesq
# 10      aco_notessa
# 11     aco_notesytd
# 12       aco_pnfnda
# 13       aco_pnfndq
# 14     aco_pnfndytd
# 15       aco_pnfnta
# 16       aco_pnfntq
# 17     aco_pnfntytd
# 18       aco_transa
# 19       aco_transq
# 20      aco_transsa
# 21     aco_transytd
# 22         adsprate
# 23        asec_amda
# 24        asec_imda
# 25      asec_notesa
# 26      asec_notesq
# 27      asec_transa
# 28      asec_transq
# 29    bank_aacctchg
# 30     bank_adesind
# 31       bank_afnd1
# 32       bank_afnd2
# 33     bank_afnddc1
# 34     bank_afnddc2
# 35     bank_afntind
# 36       bank_funda
# 37  bank_funda_fncd
# 38       bank_fundq
# 39  bank_fundq_fncd
# 40    bank_iacctchg
# 41     bank_idesind
# 42       bank_ifndq
# 43     bank_ifndytd
# 44       bank_ifntq
# 45     bank_ifntytd
# 46       bank_names
# 47      bank_namesq
# 48            chars
# 49      co_aacctchg
# 50        co_aaudit
# 51       co_adesind
# 52       co_adjfact
# 53         co_afnd1
# 54         co_afnd2
# 55       co_afnddc1
# 56       co_afnddc2
# 57      co_afntind1
# 58      co_afntind2
# 59       co_ainvval
# 60          co_amkt
# 61      co_busdescl
# 62        co_cotype
# 63      co_filedate
# 64       co_fortune
# 65          co_hgic
# 66      co_iacctchg
# 67        co_iaudit
# 68       co_idesind
# 69         co_ifndq
# 70        co_ifndsa
# 71       co_ifndytd
# 72         co_ifntq
# 73        co_ifntsa
# 74       co_ifntytd
# 75          co_imkt
# 76      co_industry
# 77          co_ipcd
# 78         co_mthly
# 79       co_offtitl
# 80          company
# 81         currency
# 82         dd_group
# 83    dd_group_xref
# 84          dd_item
# 85       dd_package
# 86       ecind_desc
# 87        ecind_mth
# 88         exrt_dly
# 89         exrt_mth
# 90          filings
# 91            funda
# 92       funda_fncd
# 93            fundq
# 94       fundq_fncd
# 95          g_chars
# 96      g_co_aaudit
# 97     g_co_adesind
# 98       g_co_afnd1
# 99       g_co_afnd2

# %% [markdown]
# ### All variables in compm.funda

# %%
db.describe_table(library="comp", table="funda")
# Out:
# Approximately 869854 rows in comp.funda.
#          name  nullable              type comment
# 0       gvkey      True        VARCHAR(6)    None
# 1    datadate      True              DATE    None
# 2       fyear      True  DOUBLE_PRECISION    None
# 3      indfmt      True       VARCHAR(12)    None
# 4      consol      True        VARCHAR(2)    None
# ..        ...       ...               ...     ...
# 943        au      True        VARCHAR(8)    None
# 944      auop      True        VARCHAR(8)    None
# 945    auopic      True        VARCHAR(1)    None
# 946     ceoso      True        VARCHAR(1)    None
# 947     cfoso      True        VARCHAR(1)    None
#
# [948 rows x 4 columns]

# %% [markdown]
# #### Where to check variable definitions?
# 1. [Xpressfeed Data Items](https://wrds-web.wharton.upenn.edu/wrds/support/Data/_001Manuals%20and%20Overviews/_001Compustat/_001North%20America%20-%20Global%20-%20Bank/_000dataguide/index.cfm?_ga=2.238205512.977702200.1550764493-1500651139.1501534854)
# 2. WRDS website: go to the (?) sign
# 3. What if we want to replicate a paper that says:
#
#    "Earnings (E) is income before extraordinary items (Item 18) plus income statement deferred taxes (Item 50) minus preferred dividends (Item 19), if earnings are positive;" [Baker and Wurgler, JF 2006](https://onlinelibrary.wiley.com/doi/epdf/10.1111/j.1540-6261.2006.00885.x)
#
#     * All previous documentation does not contain ITEM numbers
#     * These are the legacy CST item numbers
#     * You can find item reference [here](http://www.crsp.com/products/documentation/annual-data-industrial).

# %% [markdown]
# **Objective**
#
# Create a data frame with company fundamentals necessary to replicate FF 2015:
#
# 1. Book Equity (BE)
# 2. Operating Profits (OP)
# 3. Investment (INV)

# %% [markdown]
# # Choose variables of interest

# %% [markdown]
# Compustat XpressFeed Variables 1/5:
# * AT      = Total Assets
# * CAPX    = Capital Expenditures
# * CEQ     = Common/Ordinary Equity - Total
# * COGS    = Cost of Goods Sold
# * CSHO    = Common Shares Outstanding
# * DLC     = Debt in Current Liabilities
# * DLCCH   = Current Debt - Changes
# * DLTT    = Long-Term Debt - Total

# %% [markdown]
# Compustat XpressFeed Variables 2/5:
# * DP      = Depreciation and Amortization
# * DVC     = Divdends common/ordinary
# * DVP     = Dividends - Preferred/Preference
# * GP      = Gross Profits
# * IB      = Income Before Extraordinary Items
# * ICAPT   = Invested Capital - Total
# * ITCB    = Investment Tax Credit (Balance Sheet)
# * LT      = Total Liabilities

# %% [markdown]
# Compustat XpressFeed Variables 3/5:
# * MIB     = Minority Interest (Balance Sheet)
# * NAICS   = North American Industrial Classification System Variable Name
# * NAICSH  = North American Industry Classification Codes - Historical Company Variable Name
# * NI      = Net Income
# * PPEGT   = "Property, Plant and Equipment - Total (Gross)"
# * PRBA    = Postretirement Benefit Assets (from separate pension annual file)
# * PRSTKCC = Purchase of Common Stock (Cash Flow)
# * PSTKRV  = Preferred Stock Redemption Value

# %% [markdown]
# Compustat XpressFeed Variables 4/5:
# * PSTK    = Preferred/Preference Stock (Capital) - Total (kd: = par?)
# * PSTKL   = Preferred Stock Liquidating Value
# * PSTKRV  = Preferred Stock Liquidating Value
# * RE      = Retained Earnings
# * REVT    = Revenue - Total
# * SALE    = Sales/Turnover Net
# * SEQ     = Shareholders Equity
# * SIC     = Standard Industrial Classification Code

# %% [markdown]
# Compustat XpressFeed Variables 5/5:
# * TXDB    = Deferred Taxes Balance Sheet
# * TXDI    = Income Taxes - Deferred
# * TXDITC  = Deferred Taxes and Investment Tax Credit
# * WCAPCH  = Working Capital Change - Total
# * XINT    = Interest and Related Expense - Total
# * XLR     = Staff Expense - Total
# * XRD     = Research and Development Expense
# * XSGAQ   = Selling, General and Administrative Expenses (millions)

# %% [markdown]
# # Download Compustat FUNDA

# %%
fund_table = 'funda'

varlist = ['conm', 'tic', 'cusip','fyear', 'fyr', 'at','capx', 'ceq', 'cogs', 'csho', 'dlc', 'dlcch','dltt', 'dp', 'ib', 'itcb', 
           'lt', 'mib', 'naicsh', 'ni', 'prstkcc', 'pstk', 'pstkl', 'pstkrv', 're', 'revt', 'sale', 
           'seq', 'sich', 'txdb', 'txdi', 'txditc', 'wcapch', 'xint', 'xlr', 'xrd', 'xsga']


query = """SELECT gvkey, datadate, {}
           FROM comp.{}
           WHERE datafmt = 'STD'
           AND popsrc = 'D'
           AND indfmt = 'INDL'
           AND consol = 'C'
           AND fyear>=1980;""".format(", ".join(varlist), fund_table)

compa = db.raw_sql(query, date_cols=['datadate'])

del(fund_table, varlist, query)

# %% [markdown]
# Always look at your data

# %%
# Gerneral Look
compa.head()
# Out:
#     gvkey   datadate                     conm    tic      cusip   fyear   fyr  \
# 0  001001 1980-12-31  A & M FOOD SERVICES INC  AMFD.  000165100  1980.0  12.0
# 1  001001 1981-12-31  A & M FOOD SERVICES INC  AMFD.  000165100  1981.0  12.0
# 2  001001 1982-12-31  A & M FOOD SERVICES INC  AMFD.  000165100  1982.0  12.0
# 3  001001 1983-12-31  A & M FOOD SERVICES INC  AMFD.  000165100  1983.0  12.0
# 4  001001 1984-12-31  A & M FOOD SERVICES INC  AMFD.  000165100  1984.0  12.0
#
#        at   capx    ceq  ...    seq  sich   txdb   txdi  txditc  wcapch  \
# 0     NaN    NaN    NaN  ...    NaN   NaN    NaN    NaN     NaN     NaN
# 1     NaN    NaN    NaN  ...    NaN   NaN    NaN    NaN     NaN     NaN
# 2     NaN    NaN    NaN  ...    NaN   NaN    NaN    NaN     NaN     NaN
# 3  14.080  3.367  7.823  ...  7.823   NaN  0.000  0.144   0.000   3.618
# 4  16.267  5.496  8.962  ...  8.962   NaN  0.357  0.275   0.357  -2.993
#
#     xint  xlr  xrd    xsga
# 0    NaN  NaN  NaN     NaN
# 1    NaN  NaN  NaN     NaN
# 2    NaN  NaN  NaN     NaN
# 3  0.763  NaN  0.0  16.435
# 4  0.661  NaN  NaN  20.628
#
# [5 rows x 39 columns]

# %%
# Have a sense about missings
compa['at'].isnull().mean()*100
# Out:
# 17.04857022338612

# %%
compa.gvkey.nunique()
# Out:
# 40577

# %%
compa.groupby('fyear').gvkey.nunique()
# Out:
# fyear
# 1980.0     6889
# 1981.0     7058
# 1982.0     7685
# 1983.0     7996
# 1984.0     8243
# 1985.0     8599
# 1986.0     9017
# 1987.0     9225
# 1988.0     9333
# 1989.0     9343
# 1990.0     9571
# 1991.0     9966
# 1992.0    10705
# 1993.0    11482
# 1994.0    11899
# 1995.0    12492
# 1996.0    12624
# 1997.0    12437
# 1998.0    12554
# 1999.0    12531
# 2000.0    12093
# 2001.0    11583
# 2002.0    11252
# 2003.0    11066
# 2004.0    10900
# 2005.0    10856
# 2006.0    10878
# 2007.0    10874
# 2008.0    10684
# 2009.0    10637
# 2010.0    10856
# 2011.0    11271
# 2012.0    11784
# 2013.0    11844
# 2014.0    11657
# 2015.0    11494
# 2016.0    11367
# 2017.0    11280
# 2018.0    11372
# 2019.0    11594
# 2020.0    11690
# 2021.0    11680
# 2022.0     6802
# Name: gvkey, dtype: int64

# %% [markdown]
# # Data Consistency

# %% [markdown]
# ## Primary Keys
#
#
# * We are looking at Annual data
# * Logic says that that we should have one company (gvkey) per year (fyear)
# * But remember, the primary key for funda is (gvkey and datadate)
# * Question: Can a firm have two datadate for the same year?

# %%
# It is always good to check if we have the right PK
compa.duplicated(['gvkey', 'datadate']).sum()
# Out:
# 0

# %%
# Is (gvkey, fyear) PK?
compa[compa.duplicated(['gvkey', 'fyear'])]
# Out:
#          gvkey   datadate                       conm   tic      cusip   fyear  \
# 66263   006557 1982-12-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1982.0
# 66265   006557 1983-12-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1983.0
# 295709  039310 2021-01-31    VICTORIAS SECRET AND CO  VSCO  926400102  2020.0
# 334821  066552 2015-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2015.0
# 334825  066552 2016-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2016.0
# 334829  066552 2017-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2017.0
# 334831  066552 2018-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2018.0
# 334839  066552 2019-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2019.0
# 334850  066552 2010-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2010.0
# 334852  066552 2011-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2011.0
# 334854  066552 2012-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2012.0
# 334856  066552 2013-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2013.0
# 334857  066552 2014-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2014.0
#
#          fyr      at   capx    ceq  ...    seq    sich  txdb  txdi  txditc  \
# 66263   12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 66265   12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 295709   1.0  4229.0  127.0  891.0  ...  891.0  5621.0  19.0 -64.0    19.0
# 334821  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334825  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334829  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334831  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334839  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334850  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334852  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334854  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334856  12.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 334857   6.0     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
#
#         wcapch  xint  xlr  xrd    xsga
# 66263      NaN   NaN  NaN  NaN     NaN
# 66265      NaN   NaN  NaN  NaN     NaN
# 295709     NaN   6.0  NaN  0.0  1621.0
# 334821     NaN   NaN  NaN  NaN     NaN
# 334825     NaN   NaN  NaN  NaN     NaN
# 334829     NaN   NaN  NaN  NaN     NaN
# 334831     NaN   NaN  NaN  NaN     NaN
# 334839     NaN   NaN  NaN  NaN     NaN
# 334850     NaN   NaN  NaN  NaN     NaN
# 334852     NaN   NaN  NaN  NaN     NaN
# 334854     NaN   NaN  NaN  NaN     NaN
# 334856     NaN   NaN  NaN  NaN     NaN
# 334857     NaN   NaN  NaN  NaN     NaN
#
# [13 rows x 39 columns]

# %%
compa[compa.gvkey=='006557']
# Out:
#         gvkey   datadate                       conm   tic      cusip   fyear  \
# 66260  006557 1980-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1980.0
# 66261  006557 1981-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1981.0
# 66262  006557 1982-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1982.0
# 66263  006557 1982-12-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1982.0
# 66264  006557 1983-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1983.0
# 66265  006557 1983-12-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1983.0
# 66266  006557 1984-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1984.0
# 66267  006557 1985-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1985.0
# 66268  006557 1986-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1986.0
# 66269  006557 1987-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1987.0
# 66270  006557 1988-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1988.0
# 66271  006557 1989-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1989.0
# 66272  006557 1990-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1990.0
# 66273  006557 1991-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1991.0
# 66274  006557 1992-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1992.0
# 66275  006557 1993-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1993.0
# 66276  006557 1994-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1994.0
# 66277  006557 1995-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1995.0
# 66278  006557 1996-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1996.0
# 66279  006557 1997-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1997.0
# 66280  006557 1998-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1998.0
# 66281  006557 1999-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1999.0
# 66282  006557 2000-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  2000.0
# 66283  006557 2001-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  2001.0
# 66284  006557 2002-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  2002.0
# 66285  006557 2003-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  2003.0
# 66286  006557 2004-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  2004.0
# 66287  006557 2005-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  2005.0
# 66288  006557 2006-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  2006.0
#
#         fyr        at     capx       ceq  ...       seq    sich     txdb  \
# 66260   8.0   201.266   38.344    50.957  ...    73.039     NaN   14.636
# 66261   8.0   242.081   53.382    59.995  ...    81.481     NaN   18.192
# 66262   8.0   251.360   47.089    63.491  ...    84.314     NaN   19.938
# 66263  12.0       NaN      NaN       NaN  ...       NaN     NaN      NaN
# 66264   8.0   328.891   78.264   103.481  ...   120.161     NaN   25.469
# 66265  12.0       NaN      NaN       NaN  ...       NaN     NaN      NaN
# 66266   8.0   426.880   93.098   177.188  ...   191.757     NaN   31.525
# 66267   8.0   652.477  149.695   225.685  ...   357.124     NaN   34.765
# 66268   8.0   901.769  149.687   406.137  ...   537.574     NaN   36.442
# 66269   8.0  1655.019  242.522   821.060  ...  1138.647  4953.0   38.797
# 66270   8.0  1636.927  244.666   755.048  ...   906.630  4953.0   43.807
# 66271   8.0  2651.276  187.868  1330.093  ...  1477.194  4953.0   63.812
# 66272   8.0  3894.939  271.309  1906.825  ...  2053.867  4953.0   88.617
# 66273   8.0  3595.316  248.448  1672.454  ...  1682.063  4953.0   89.781
# 66274   8.0  3658.935  208.723  1950.345  ...  1959.954  4953.0   88.800
# 66275   8.0  3575.082  200.712  1543.701  ...  1553.310  4953.0   43.904
# 66276   8.0  3633.200  273.000  1576.300  ...  1585.900  4953.0   48.200
# 66277   8.0  4286.300  316.700  1688.100  ...  1697.400  4953.0   46.000
# 66278   8.0  4932.300  289.100  2127.800  ...  2136.800  4100.0  131.500
# 66279   8.0  6117.100  237.100  2785.300  ...  2794.000  4100.0   52.900
# 66280   8.0  6184.600  312.900  3081.500  ...  3089.900  4100.0    0.000
# 66281   8.0  5754.300  278.600  1905.100  ...  1913.100  4100.0    0.000
# 66282   8.0  4000.100  330.400  -384.900  ...  -377.000  4100.0    0.000
# 66283   8.0  4209.800  267.300  -988.400  ...  -980.500  4100.0    0.000
# 66284   8.0  4091.100  283.300 -1114.900  ... -1107.000  4100.0    0.000
# 66285   8.0  3852.700  320.600  1290.300  ...  1290.300  4100.0    0.000
# 66286   8.0  3905.200  224.900  1376.500  ...  1376.500  4100.0    0.000
# 66287   8.0  2908.700  186.600  1600.200  ...  1600.200  4100.0    0.000
# 66288   8.0  3038.700  329.300  1207.900  ...  1207.900  4100.0    0.000
#
#           txdi   txditc   wcapch     xint  xlr  xrd     xsga
# 66260    3.474   14.636      NaN    7.208  NaN  NaN      NaN
# 66261    3.276   18.192      NaN   11.743  NaN  NaN      NaN
# 66262    2.672   19.938   13.777   14.309  NaN  NaN      NaN
# 66263      NaN      NaN      NaN      NaN  NaN  NaN      NaN
# 66264    5.533   25.469    3.109    8.879  NaN  NaN   17.218
# 66265      NaN      NaN      NaN      NaN  NaN  NaN      NaN
# 66266    7.398   31.525   19.261   10.364  NaN  NaN   24.115
# 66267    7.129   34.765  111.813   15.567  NaN  NaN   32.761
# 66268   14.026   36.442      NaN   20.606  NaN  NaN   43.760
# 66269   14.087   38.797      NaN   41.287  NaN  NaN   71.831
# 66270   15.992   43.807      NaN   28.167  NaN  NaN   69.630
# 66271   16.819   63.812      NaN   65.401  NaN  NaN   87.697
# 66272    9.590   88.617      NaN  112.962  NaN  NaN  120.709
# 66273    0.750   89.781      NaN  133.106  NaN  NaN  161.928
# 66274   13.150   88.800      NaN  122.114  NaN  NaN  152.226
# 66275  -48.000   43.904      NaN  105.655  NaN  NaN  158.247
# 66276   10.000   48.200      NaN  116.500  NaN  NaN  159.800
# 66277   19.200   46.000      NaN  133.200  NaN  NaN  171.100
# 66278    9.000  131.500      NaN  107.600  NaN  NaN  145.800
# 66279 -126.200   52.900      NaN  137.500  NaN  NaN  199.500
# 66280   16.600    0.000      NaN  177.000  NaN  NaN  240.600
# 66281    8.200    0.000      NaN   91.800  NaN  NaN  243.800
# 66282   19.100    0.000      NaN  207.100  NaN  NaN  375.900
# 66283    0.000    0.000      NaN  270.900  NaN  NaN  460.700
# 66284    0.000    0.000      NaN   27.700  NaN  NaN  459.300
# 66285   -5.500    0.000      NaN   51.100  NaN  NaN  490.200
# 66286   29.500    0.000      NaN  129.600  NaN  NaN  495.600
# 66287   -3.000    0.000      NaN   70.800  NaN  NaN  314.400
# 66288   85.300    0.000      NaN   24.300  NaN  NaN  305.900
#
# [29 rows x 39 columns]

# %%
# Check duplicates
compa[compa.duplicated(['gvkey', 'fyear'],keep='last')]
# Out:
#          gvkey   datadate                       conm   tic      cusip   fyear  \
# 66262   006557 1982-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1982.0
# 66264   006557 1983-08-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102  1983.0
# 295707  039310 2020-12-31    VICTORIAS SECRET AND CO  VSCO  926400102  2020.0
# 334819  066552 2014-12-31   LIMITLESS X HOLDINGS INC  VYBE  090622309  2014.0
# 334820  066552 2015-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2015.0
# 334824  066552 2016-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2016.0
# 334826  066552 2017-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2017.0
# 334830  066552 2018-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2018.0
# 334835  066552 2019-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2019.0
# 334849  066552 2010-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2010.0
# 334851  066552 2011-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2011.0
# 334853  066552 2012-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2012.0
# 334855  066552 2013-06-30   LIMITLESS X HOLDINGS INC  VYBE  090622309  2013.0
#
#          fyr       at    capx      ceq  ...      seq  sich    txdb   txdi  \
# 66262    8.0  251.360  47.089   63.491  ...   84.314   NaN  19.938  2.672
# 66264    8.0  328.891  78.264  103.481  ...  120.161   NaN  25.469  5.533
# 295707  12.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334819  12.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334820   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334824   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334826   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334830   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334835   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334849   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334851   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334853   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
# 334855   6.0      NaN     NaN      NaN  ...      NaN   NaN     NaN    NaN
#
#         txditc  wcapch    xint  xlr  xrd    xsga
# 66262   19.938  13.777  14.309  NaN  NaN     NaN
# 66264   25.469   3.109   8.879  NaN  NaN  17.218
# 295707     NaN     NaN     NaN  NaN  NaN     NaN
# 334819     NaN     NaN     NaN  NaN  NaN     NaN
# 334820     NaN     NaN     NaN  NaN  NaN     NaN
# 334824     NaN     NaN     NaN  NaN  NaN     NaN
# 334826     NaN     NaN     NaN  NaN  NaN     NaN
# 334830     NaN     NaN     NaN  NaN  NaN     NaN
# 334835     NaN     NaN     NaN  NaN  NaN     NaN
# 334849     NaN     NaN     NaN  NaN  NaN     NaN
# 334851     NaN     NaN     NaN  NaN  NaN     NaN
# 334853     NaN     NaN     NaN  NaN  NaN     NaN
# 334855     NaN     NaN     NaN  NaN  NaN     NaN
#
# [13 rows x 39 columns]

# %%
# Example of a company that have two reports for the same year
compa.loc[compa.gvkey=='006557',['gvkey','datadate','fyear','fyr','conm', 'at']]
# Out:
#         gvkey   datadate   fyear   fyr                       conm        at
# 66260  006557 1980-08-31  1980.0   8.0  LAIDLAW INTERNATIONAL INC   201.266
# 66261  006557 1981-08-31  1981.0   8.0  LAIDLAW INTERNATIONAL INC   242.081
# 66262  006557 1982-08-31  1982.0   8.0  LAIDLAW INTERNATIONAL INC   251.360
# 66263  006557 1982-12-31  1982.0  12.0  LAIDLAW INTERNATIONAL INC       NaN
# 66264  006557 1983-08-31  1983.0   8.0  LAIDLAW INTERNATIONAL INC   328.891
# 66265  006557 1983-12-31  1983.0  12.0  LAIDLAW INTERNATIONAL INC       NaN
# 66266  006557 1984-08-31  1984.0   8.0  LAIDLAW INTERNATIONAL INC   426.880
# 66267  006557 1985-08-31  1985.0   8.0  LAIDLAW INTERNATIONAL INC   652.477
# 66268  006557 1986-08-31  1986.0   8.0  LAIDLAW INTERNATIONAL INC   901.769
# 66269  006557 1987-08-31  1987.0   8.0  LAIDLAW INTERNATIONAL INC  1655.019
# 66270  006557 1988-08-31  1988.0   8.0  LAIDLAW INTERNATIONAL INC  1636.927
# 66271  006557 1989-08-31  1989.0   8.0  LAIDLAW INTERNATIONAL INC  2651.276
# 66272  006557 1990-08-31  1990.0   8.0  LAIDLAW INTERNATIONAL INC  3894.939
# 66273  006557 1991-08-31  1991.0   8.0  LAIDLAW INTERNATIONAL INC  3595.316
# 66274  006557 1992-08-31  1992.0   8.0  LAIDLAW INTERNATIONAL INC  3658.935
# 66275  006557 1993-08-31  1993.0   8.0  LAIDLAW INTERNATIONAL INC  3575.082
# 66276  006557 1994-08-31  1994.0   8.0  LAIDLAW INTERNATIONAL INC  3633.200
# 66277  006557 1995-08-31  1995.0   8.0  LAIDLAW INTERNATIONAL INC  4286.300
# 66278  006557 1996-08-31  1996.0   8.0  LAIDLAW INTERNATIONAL INC  4932.300
# 66279  006557 1997-08-31  1997.0   8.0  LAIDLAW INTERNATIONAL INC  6117.100
# 66280  006557 1998-08-31  1998.0   8.0  LAIDLAW INTERNATIONAL INC  6184.600
# 66281  006557 1999-08-31  1999.0   8.0  LAIDLAW INTERNATIONAL INC  5754.300
# 66282  006557 2000-08-31  2000.0   8.0  LAIDLAW INTERNATIONAL INC  4000.100
# 66283  006557 2001-08-31  2001.0   8.0  LAIDLAW INTERNATIONAL INC  4209.800
# 66284  006557 2002-08-31  2002.0   8.0  LAIDLAW INTERNATIONAL INC  4091.100
# 66285  006557 2003-08-31  2003.0   8.0  LAIDLAW INTERNATIONAL INC  3852.700
# 66286  006557 2004-08-31  2004.0   8.0  LAIDLAW INTERNATIONAL INC  3905.200
# 66287  006557 2005-08-31  2005.0   8.0  LAIDLAW INTERNATIONAL INC  2908.700
# 66288  006557 2006-08-31  2006.0   8.0  LAIDLAW INTERNATIONAL INC  3038.700

# %%
# How to deal with duplicates? Keep last available entry (datadate)
compa.dropna(subset=['fyear'], inplace=True)
compa.sort_values(['gvkey','fyear','at'], inplace=True)
compa = compa[~compa.duplicated(['gvkey', 'fyear'], keep='first')]

# %%
# Always check your result
compa.duplicated(['gvkey', 'fyear']).sum()
# Out:
# 0

# %% [markdown]
# # Calculate Variables of Interest

# %% [markdown]
# ## Book Equity
#
# Daniel, Mota, Rottke, Santos (RFS, 2020) BE definition:
#
# Stockholders book equity, minus the book value of preferred stock, plus balance sheet deferred taxes (if available and fiscal year is < 1993), minus investment tax credit (if available), minus post-retirement benefit assets (PRBA) if available.
#
# Stockholders book equity is shareholder equity (SEQ), common equity (CEQ) plus preferred stock (PSTK) or total
# assets (AT) minus liabilities (LT) plus minority interest (MIB, if available) (depending on availability, in that order).
#
# Book value of preferred stock is redemption (PSTKRV), liquidation (PSTKL), or par value (PSTK) (depending on availability, in that order).
#
# Deferred taxes is deferred taxes and investment tax credit (TXDITC) or deferred taxes and investment tax credit (TXDB) plus investment tax credit (ITCB) (depending on availability, in that order).

# %%
#%% Calculating BE

# Shareholder Equity
compa['se'] = compa['seq']

# Uses Common Equity (ceq) + Preferred Stock (pstk) if SEQ is missing:
compa['se'].fillna((compa['ceq'] + compa['pstk']), inplace=True)

# Uses Total Assets (at) - Liabilities (lt) + Minority Interest (mib, if available), if others are missing
compa['se'].fillna((compa['at'] - compa['lt'] + compa['mib'].fillna(0)), inplace=True)

# %%
# Preferred Stock
# Preferred Stock (Redemption Value)
compa['ps'] = compa['pstkrv']
# Uses Preferred Stock (Liquidating Value (pstkl)) if Preferred Stock (Redemption Value) is missing
compa['ps'].fillna(compa['pstkl'], inplace=True)
# Uses Preferred Stock (Carrying Value (pstk)) if others are missing
compa['ps'].fillna(compa['pstk'], inplace=True)

# %%
# Deferred Taxes
# Uses Deferred Taxes and Investment Tax Credit (txditc)
compa['dt'] = compa['txditc']

# This was Novy-Marx old legacy code. We drop this part to be in accordance with Ken French.
# Uses Deferred Taxes and Investment Tax Credit(txdb) + Investment Tax Credit (Balance Sheet) (itcb) if txditc is missing
compa['dt'].fillna((compa['txdb'].fillna(0) + compa['itcb'].fillna(0)), inplace=True)
# If all measures are missing, set n  to missing
compa.loc[pd.isnull(compa['txditc']) & pd.isnull(compa['txdb']) & pd.isnull(compa['itcb']), 'dt'] = np.nan

compa.loc[compa['fyear'] >= 1993, 'dt'] = 0

# %%
# Book Equity
# Book Equity (BE) = Share Equity (se) - Prefered Stocks (ps) + Deferred Taxes (dt)
compa['be'] = (compa['se']  # shareholder equity must be available, otherwise BE is missing
               - compa['ps']  # preferred stock must be available, otherwise BE is missing
               + compa['dt'].fillna(0))  # add deferred taxes if available
               #- compa['prba'].fillna(0))  # subtract postretirement benefit assets if available

# %% [markdown]
# **Always look at your data...**

# %%
# Missings
compa.be.isnull().mean()
# Out:
# 0.17220863734530267

# %%
compa.be.hist()
# Out:
# <AxesSubplot:>

# %%
# Does it make sense to have a negative BE?
(compa.be<0).mean()
# Out:
# 0.09679389581314826

# %%
compa[compa.be>0].be.hist()
# Out:
# <AxesSubplot:>

# %%
compa[(compa.be>0)&(compa.be<10e3)&(compa.fyear==2017)].be.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Operating Profitability (OPBE)
#
# Daniel, Mota, Rottke, Santos (RFS, 2020) OPBE definition:
#
# Operating profits to book equity (BE) ratio.
#
# Operating profits is sales (SALE) minus cost of goods sold (COGS), minus selling, general, and administrative expenses (XSGA),
# minus interest expense (XINT). In order to be non-missing, SALE must be non-missing, at least one of the other entries must be non-missing and BE must be greater than zero.

# %%
# COST = COGS + XSGA + XINT 
compa['cost'] = compa[['cogs', 'xsga', 'xint']].sum(axis=1, skipna=True)
compa.loc[compa[['cogs', 'xsga', 'xint']].isnull().all(axis=1), 'cost'] = np.nan

# %%
# OP = SALE -COST    
compa['op'] = compa['sale']-compa['cost']

# %% [markdown]
# **Always look at your data...**

# %%
# Look at missings
compa.op.isnull().mean()
# Out:
# 0.17625334220927447

# %%
compa[compa.fyear==2017].op.hist()
# Out:
# <AxesSubplot:>

# %%
# Which was the most profitable company in 2017?
compa.loc[compa[compa.fyear==2017].op.idxmax(),['gvkey','conm','op','be','at']]
# Out:
# gvkey         015532
# conm     BNP PARIBAS
# op         73500.106
# be        122603.963
# at       2356614.954
# Name: 177280, dtype: object

# %%
# Plot
compa[compa.gvkey=='001690'].set_index('fyear').op.plot(title = "Apple's OP", grid=True)
# Out:
# <AxesSubplot:title={'center':"Apple's OP"}, xlabel='fyear'>

# %%
# Calculate OPBE
compa.loc[(compa.be > 0), 'opbe'] = compa['op']/compa['be']

# %% [markdown]
# **What do we do now?**

# %% [markdown]
# Look at the data...

# %%
# Look at missings
compa.opbe.isnull().mean()
# Out:
# 0.27462689190465833

# %%
# Be careful with ratios
compa.opbe.hist()
# Out:
# <AxesSubplot:>

# %%
# Plot
compa[compa.gvkey=='001690'].set_index('fyear').opbe.plot(title = "Apple's OPBE", grid=True)

# plot both on log scale and show difference
# Out:
# <AxesSubplot:title={'center':"Apple's OPBE"}, xlabel='fyear'>

# %% [markdown]
# ## Investment (INV)
#
# Daniel, Mota, Rottke, Santos (RFS, 2020) OP definition:
#
# Total asset (AT) growth $(AT_t/AT_{t-1} - 1)$.
#
# We consider PERMCO as company's identification key. AT must be greater than zero to be not missing.

# %%
# Calculate lag assets and investment
compa.sort_values(['gvkey', 'fyear'], inplace=True)
compa['at_lag'] = compa.groupby('gvkey').at.shift(1)
compa['inv'] = (compa['at'] - compa['at_lag']) / compa['at_lag']

# %%
compa.inv.max()
# Out:
# inf

# %%
compa.inv.min()
# Out:
# -1.0

# %%
compa.loc[compa.at_lag==0, 'inv'] = np.nan

# %% [markdown]
# What if compa has missing years?

# %%
compa['fdiff'] = compa.groupby('gvkey').fyear.diff()

# %%
compa[(compa.fdiff>1)][['gvkey','fyear','fdiff', 'at','at_lag', 'inv']]
# Out:
#          gvkey   fyear  fdiff         at     at_lag        inv
# 21461   002820  2001.0    4.0    117.090        NaN        NaN
# 27385   003279  2011.0   19.0        NaN      1.269        NaN
# 29493   003469  2002.0    4.0    406.677        NaN        NaN
# 33017   003819  2011.0   19.0        NaN      2.295        NaN
# 36110   004049  2000.0    4.0    905.890        NaN        NaN
# 39241   004292  2012.0    3.0      0.704      0.534   0.318352
# 39780   004341  2000.0    2.0      0.000        NaN        NaN
# 40543   004412  2004.0    2.0    213.432    218.681  -0.024003
# 40546   004412  2008.0    2.0    219.640    203.755   0.077961
# 44282   004707  1996.0    3.0     14.416        NaN        NaN
# 49977   005202  1999.0   14.0      0.000      0.102  -1.000000
# 55398   005681  1995.0    4.0     26.851  13885.098  -0.998066
# 56674   005792  1998.0   13.0    218.462     84.850   1.574685
# 57143   005835  1997.0   16.0      0.030      3.052  -0.990170
# 59124   006000  2010.0   20.0        NaN      6.091        NaN
# 64584   006423  2011.0   22.0        NaN     38.823        NaN
# 65036   006464  1998.0   13.0      0.027      1.553  -0.982614
# 71947   007102  2011.0   19.0        NaN      1.687        NaN
# 73121   007185  2000.0    2.0    139.946    182.059  -0.231315
# 81331   007860  1998.0    2.0      0.423        NaN        NaN
# 85497   008145  2010.0   20.0        NaN     89.088        NaN
# 91201   008605  2001.0    3.0   2745.536        NaN        NaN
# 100908  009455  2007.0    4.0     17.965     20.144  -0.108171
# 101416  009493  2011.0   19.0        NaN      0.829        NaN
# 116050  010734  2019.0    4.0      2.992      3.784  -0.209302
# 117127  010820  2011.0   19.0        NaN      1.138        NaN
# 121056  011137  2011.0   20.0        NaN     75.795        NaN
# 123458  011332  1998.0   11.0      0.054      2.970  -0.981818
# 126705  011611  1997.0   15.0      0.007      1.041  -0.993276
# 129744  011878  2011.0   19.0        NaN      0.875        NaN
# 132335  012132  1998.0   10.0      0.000      1.311  -1.000000
# 132781  012161  2011.0   19.0        NaN     77.187        NaN
# 133943  012286  1996.0    6.0      0.839      1.293  -0.351121
# 134939  012324  2010.0   18.0        NaN      0.138        NaN
# 144313  013212  2011.0   20.0        NaN     16.418        NaN
# 152676  013712  2009.0    2.0   1580.300        NaN        NaN
# 152896  013744  1990.0    4.0        NaN      1.028        NaN
# 154726  013936  1998.0    2.0      0.016        NaN        NaN
# 146993  013958  2011.0   21.0        NaN  11310.898        NaN
# 155274  013973  2005.0    6.0    121.222    751.055  -0.838598
# 156283  014038  2011.0   20.0        NaN     24.309        NaN
# 158348  014186  2001.0    4.0    160.347        NaN        NaN
# 163023  014488  2011.0   20.0        NaN   3453.626        NaN
# 163401  014546  1985.0    2.0     55.660        NaN        NaN
# 164446  014582  1998.0    2.0      0.085        NaN        NaN
# 164951  014608  2011.0   21.0        NaN     43.322        NaN
# 161951  014660  2007.0    3.0        NaN        NaN        NaN
# 167176  014783  2004.0   10.0        NaN        NaN        NaN
# 169394  014955  1997.0    9.0      0.747      6.741  -0.889186
# 169812  014995  2007.0    3.0        NaN        NaN        NaN
# 175150  015355  2011.0   21.0        NaN     88.760        NaN
# 180289  016445  2005.0    8.0        NaN        NaN        NaN
# 180909  016482  2010.0   20.0        NaN      2.202        NaN
# 188601  017238  2010.0   20.0        NaN      1.816        NaN
# 190409  017616  1998.0    6.0    159.707        NaN        NaN
# 202721  020115  2012.0    4.0    440.908    325.075   0.356327
# 204230  020305  2000.0    4.0   4430.102    637.436   5.949877
# 207338  020704  1994.0    2.0     13.574        NaN        NaN
# 208334  020866  1991.0    2.0     82.200        NaN        NaN
# 213163  021829  2011.0   21.0        NaN      5.289        NaN
# 213614  021943  2017.0    2.0        NaN        NaN        NaN
# 215307  022251  2011.0   20.0        NaN      2.535        NaN
# 221812  023714  1998.0    3.0   1747.016    567.713   2.077287
# 229163  024683  2006.0    2.0        NaN        NaN        NaN
# 226994  024739  2006.0    2.0        NaN        NaN        NaN
# 229870  024741  1999.0    2.0      0.286        NaN        NaN
# 230446  024787  1998.0    5.0    328.283    172.455   0.903586
# 230657  024805  2007.0    3.0        NaN        NaN        NaN
# 233497  025064  2006.0    2.0        NaN        NaN        NaN
# 238130  025586  1998.0    3.0    231.130    285.850  -0.191429
# 234379  025597  2007.0    2.0        NaN        NaN        NaN
# 243889  026136  1992.0    2.0      3.003        NaN        NaN
# 245129  026379  2017.0    4.0     66.787    106.559  -0.373239
# 246251  026718  2000.0    3.0      1.983      0.302   5.566225
# 246991  027854  2007.0    2.0        NaN        NaN        NaN
# 251429  027947  2007.0    2.0        NaN        NaN        NaN
# 256540  028606  2006.0    2.0        NaN        NaN        NaN
# 259667  028826  2005.0    2.0        NaN        NaN        NaN
# 259939  028843  2007.0    3.0        NaN        NaN        NaN
# 260510  028903  2011.0    2.0   1370.560        NaN        NaN
# 258794  028911  2022.0    3.0        NaN        NaN        NaN
# 261286  029000  2004.0    7.0        NaN        NaN        NaN
# 265975  029513  2005.0    2.0        NaN    201.516        NaN
# 269536  029930  1999.0    2.0     71.801     98.245  -0.269164
# 274675  030616  1999.0    5.0      3.409      6.094  -0.440597
# 277320  031135  1996.0    2.0        NaN     69.589        NaN
# 280425  031533  2008.0    3.0    133.555    139.138  -0.040126
# 289938  035190  2021.0    2.0        NaN        NaN        NaN
# 285631  035205  2021.0    2.0        NaN        NaN        NaN
# 300160  061163  2003.0    2.0   1364.942        NaN        NaN
# 303115  061572  2004.0    4.0    288.040        NaN        NaN
# 304187  061697  2002.0    2.0    350.082    298.277   0.173681
# 304722  061745  2008.0    3.0    514.582        NaN        NaN
# 318803  064020  2005.0    2.0      0.409        NaN        NaN
# 322145  064545  2007.0    3.0        NaN        NaN        NaN
# 322388  064582  2007.0    7.0        NaN     62.376        NaN
# 323529  064745  2002.0    4.0    590.351    714.027  -0.173209
# 327311  065275  2010.0    3.0   1721.692    454.513   2.787993
# 327180  065581  2009.0    9.0   6898.722  14374.897  -0.520085
# 330997  065819  2000.0    2.0    405.504        NaN        NaN
# 331658  065916  1995.0    3.0     14.934        NaN        NaN
# 334741  066522  2007.0    2.0        NaN        NaN        NaN
# 334866  066557  2006.0    2.0      1.213      6.575  -0.815513
# 335935  066728  1998.0    2.0     23.290        NaN        NaN
# 339682  106041  2004.0    5.0      0.541      3.435  -0.842504
# 339958  106133  2006.0    2.0        NaN        NaN        NaN
# 340661  106466  2007.0    2.0     77.694        NaN        NaN
# 346583  109921  2006.0    2.0        NaN        NaN        NaN
# 347508  110804  2005.0    2.0    360.385        NaN        NaN
# 348483  111873  2010.0    3.0    501.991    342.546   0.465470
# 360469  124039  2012.0    2.0        NaN        NaN        NaN
# 363200  126697  2012.0    2.0        NaN        NaN        NaN
# 364870  129087  2012.0    2.0        NaN        NaN        NaN
# 364896  129098  2012.0    2.0        NaN        NaN        NaN
# 366655  132981  2008.0    2.0      5.072        NaN        NaN
# 367098  133346  2005.0    2.0        NaN        NaN        NaN
# 368595  135249  2012.0    2.0        NaN        NaN        NaN
# 369758  137139  2012.0    2.0        NaN        NaN        NaN
# 369799  137143  2012.0    2.0        NaN        NaN        NaN
# 371831  138981  1998.0    3.0     33.025        NaN        NaN
# 372286  140032  2012.0    2.0        NaN        NaN        NaN
# 375332  142130  2007.0    2.0        NaN        NaN        NaN
# 375440  142253  2012.0    2.0        NaN        NaN        NaN
# 376375  143466  2012.0    2.0        NaN        NaN        NaN
# 377410  143710  2008.0    4.0    301.039    366.894  -0.179493
# 378357  144217  2020.0    2.0        NaN        NaN        NaN
# 376155  144218  2020.0    2.0        NaN        NaN        NaN
# 376390  144219  2020.0    2.0        NaN        NaN        NaN
# 380092  145411  2006.0    2.0        NaN        NaN        NaN
# 380104  145412  2006.0    2.0        NaN        NaN        NaN
# 380168  145415  2006.0    2.0        NaN        NaN        NaN
# 381799  146616  2002.0    2.0     21.795      1.046  19.836520
# 384000  149265  2020.0    2.0        NaN        NaN        NaN
# 384143  149266  2020.0    2.0        NaN        NaN        NaN
# 381733  151199  2005.0    2.0        NaN        NaN        NaN
# 388695  154118  2011.0    2.0        NaN        NaN        NaN
# 388776  154118  2020.0    2.0        NaN        NaN        NaN
# 389589  154760  2004.0    2.0    276.587    243.784   0.134558
# 389378  155326  2006.0    2.0        NaN        NaN        NaN
# 390591  156520  2006.0    2.0        NaN        NaN        NaN
# 392827  157679  2011.0    4.0   3231.561        NaN        NaN
# 394248  160295  2004.0    2.0      7.969      0.313  24.460064
# 394632  160417  2017.0    2.0     70.558     93.991  -0.249311
# 395378  160681  2010.0    4.0   1041.200        NaN        NaN
# 395754  160788  2011.0    5.0    118.869    133.503  -0.109616
# 395729  160788  2018.0    5.0    159.077    123.674   0.286261
# 395979  160865  2002.0    3.0  63186.000  15843.000   2.988260
# 400188  163595  2005.0    2.0     48.185        NaN        NaN
# 401225  163863  2013.0    5.0        NaN   1402.943        NaN
# 403204  164363  2010.0    2.0   1097.900        NaN        NaN
# 406788  165878  2006.0    2.0    168.231     76.986   1.185215
# 413078  175226  2017.0    3.0        NaN        NaN        NaN
# 424075  178482  2018.0    6.0      0.000      1.615  -1.000000
# 424235  178540  2011.0    5.0   1676.700   1889.900  -0.112810
# 426784  179313  2021.0    2.0        NaN        NaN        NaN
# 427674  179671  2009.0    3.0    103.469     87.780   0.178731
# 428690  180016  2009.0    2.0   3083.156   2925.031   0.054059
# 430316  180636  2007.0    2.0    105.146        NaN        NaN
# 448999  196856  2013.0    3.0        NaN      3.891        NaN
# 450763  221237  2005.0    2.0    613.738    172.843   2.550841
# 451398  233149  2007.0    2.0    163.373    119.603   0.365961
# 451405  233491  2009.0    2.0    453.331    707.883  -0.359596
# 445956  260850  2020.0    2.0        NaN        NaN        NaN
# 453036  265008  2008.0    2.0   1405.940    399.094   2.522829

# %%
# Check one case of skipping years
compa.loc[compa.gvkey=='005681',['gvkey','fyear','at','at_lag','inv','fdiff']]
# Out:
#         gvkey   fyear         at     at_lag       inv  fdiff
# 55394  005681  1983.0   6803.074        NaN       NaN    NaN
# 55395  005681  1984.0   8885.500   6803.074  0.306101    1.0
# 55396  005681  1985.0  10018.598   8885.500  0.127522    1.0
# 55397  005681  1986.0  12074.598  10018.598  0.205218    1.0
# 55339  005681  1987.0  14109.098  12074.598  0.168494    1.0
# 55359  005681  1988.0  17008.699  14109.098  0.205513    1.0
# 55377  005681  1989.0  17766.699  17008.699  0.044565    1.0
# 55382  005681  1990.0  18259.500  17766.699  0.027737    1.0
# 54520  005681  1991.0  13885.098  18259.500 -0.239569    1.0
# 55398  005681  1995.0     26.851  13885.098 -0.998066    4.0
# 55399  005681  1996.0     17.091     26.851 -0.363487    1.0
# 55400  005681  1997.0     15.457     17.091 -0.095606    1.0
# 55401  005681  1998.0     19.043     15.457  0.231998    1.0
# 55402  005681  1999.0     27.528     19.043  0.445571    1.0
# 55403  005681  2000.0     24.818     27.528 -0.098445    1.0
# 55404  005681  2001.0     25.804     24.818  0.039729    1.0
# 55405  005681  2002.0    117.043     25.804  3.535847    1.0
# 55406  005681  2003.0    217.010    117.043  0.854105    1.0
# 55407  005681  2004.0    211.487    217.010 -0.025450    1.0
# 55408  005681  2005.0    294.261    211.487  0.391390    1.0
# 55409  005681  2006.0    237.299    294.261 -0.193576    1.0
# 55410  005681  2007.0    219.255    237.299 -0.076039    1.0
# 55411  005681  2008.0    190.397    219.255 -0.131618    1.0
# 55412  005681  2009.0    185.704    190.397 -0.024648    1.0
# 55413  005681  2010.0    184.510    185.704 -0.006430    1.0
# 55414  005681  2011.0    188.753    184.510  0.022996    1.0
# 55415  005681  2012.0    189.409    188.753  0.003475    1.0
# 55416  005681  2013.0    204.402    189.409  0.079157    1.0
# 55417  005681  2014.0    433.189    204.402  1.119299    1.0
# 55418  005681  2015.0    555.311    433.189  0.281914    1.0
# 55419  005681  2016.0    582.332    555.311  0.048659    1.0
# 55420  005681  2017.0    607.947    582.332  0.043987    1.0
# 55421  005681  2018.0    594.008    607.947 -0.022928    1.0

# %%
# Input missings
filter_inv = (compa['at']<=0)|(compa['at_lag']<=0)|(compa.fdiff>1)
compa.loc[filter_inv,['inv']] = np.nan
del(filter_inv)

# %%
# Check one case of skipping years (again)
compa.loc[compa.gvkey=='005681',['gvkey','fyear','at','at_lag','inv']]
# Out:
#         gvkey   fyear         at     at_lag       inv
# 55394  005681  1983.0   6803.074        NaN       NaN
# 55395  005681  1984.0   8885.500   6803.074  0.306101
# 55396  005681  1985.0  10018.598   8885.500  0.127522
# 55397  005681  1986.0  12074.598  10018.598  0.205218
# 55339  005681  1987.0  14109.098  12074.598  0.168494
# 55359  005681  1988.0  17008.699  14109.098  0.205513
# 55377  005681  1989.0  17766.699  17008.699  0.044565
# 55382  005681  1990.0  18259.500  17766.699  0.027737
# 54520  005681  1991.0  13885.098  18259.500 -0.239569
# 55398  005681  1995.0     26.851  13885.098       NaN
# 55399  005681  1996.0     17.091     26.851 -0.363487
# 55400  005681  1997.0     15.457     17.091 -0.095606
# 55401  005681  1998.0     19.043     15.457  0.231998
# 55402  005681  1999.0     27.528     19.043  0.445571
# 55403  005681  2000.0     24.818     27.528 -0.098445
# 55404  005681  2001.0     25.804     24.818  0.039729
# 55405  005681  2002.0    117.043     25.804  3.535847
# 55406  005681  2003.0    217.010    117.043  0.854105
# 55407  005681  2004.0    211.487    217.010 -0.025450
# 55408  005681  2005.0    294.261    211.487  0.391390
# 55409  005681  2006.0    237.299    294.261 -0.193576
# 55410  005681  2007.0    219.255    237.299 -0.076039
# 55411  005681  2008.0    190.397    219.255 -0.131618
# 55412  005681  2009.0    185.704    190.397 -0.024648
# 55413  005681  2010.0    184.510    185.704 -0.006430
# 55414  005681  2011.0    188.753    184.510  0.022996
# 55415  005681  2012.0    189.409    188.753  0.003475
# 55416  005681  2013.0    204.402    189.409  0.079157
# 55417  005681  2014.0    433.189    204.402  1.119299
# 55418  005681  2015.0    555.311    433.189  0.281914
# 55419  005681  2016.0    582.332    555.311  0.048659
# 55420  005681  2017.0    607.947    582.332  0.043987
# 55421  005681  2018.0    594.008    607.947 -0.022928

# %% [markdown]
# **What do we do now?**

# %%
# Look at missings
compa.inv.isnull().mean()
# Out:
# 0.24970834624079724

# %%
# Be careful with ratios
compa.loc[compa.inv.idxmax,['gvkey','conm','fyear','at','at_lag','inv']]
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py in _cmp_method(self, other, op)
#    1007         try:
# -> 1008             other = self._validate_comparison_value(other)
#    1009         except InvalidComparison:
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py in _validate_comparison_value(self, other)
#     541         elif not is_list_like(other):
# --> 542             raise InvalidComparison(other)
#     543
#
# InvalidComparison: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/0d/y3j6q5wn2bbg73ntj4rlww480000gq/T/ipykernel_52335/3610435141.py in <cell line: 2>()
#       1 # Be careful with ratios
# ----> 2 compa.loc[compa.inv.idxmax,['gvkey','conm','fyear','at','at_lag','inv']]
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     956         if type(key) is tuple:
#     957             key = tuple(list(x) if is_iterator(x) else x for x in key)
# --> 958             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/indexing.py in <genexpr>(.0)
#     956         if type(key) is tuple:
#     957             key = tuple(list(x) if is_iterator(x) else x for x in key)
# --> 958             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     356     """
#     357     if callable(maybe_callable):
# --> 358         return maybe_callable(obj, **kwargs)
#     359
#     360     return maybe_callable
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2402         nan
#    2403         """
# -> 2404         i = self.argmax(axis, skipna, *args, **kwargs)
#    2405         if i == -1:
#    2406             return np.nan
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/base.py in argmax(self, axis, skipna, *args, **kwargs)
#     644         """
#     645         delegate = self._values
# --> 646         nv.validate_minmax_axis(axis)
#     647         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
#     648
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/compat/numpy/function.py in validate_minmax_axis(axis, ndim)
#     406     if axis is None:
#     407         return
# --> 408     if axis >= ndim or (axis < 0 and ndim + axis < 0):
#     409         raise ValueError(f"`axis` must be fewer than the number of dimensions ({ndim})")
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/arraylike.py in __ge__(self, other)
#      58     @unpack_zerodim_and_defer("__ge__")
#      59     def __ge__(self, other):
# ---> 60         return self._cmp_method(other, operator.ge)
#      61
#      62     # -------------------------------------------------------------
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    6932
#    6933         # See GH#4537 for discussion of scalar op behavior
# -> 6934         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6935         return self._construct_result(new_data)
#    6936
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    6971             # i.e. scalar, faster than checking np.ndim(right) == 0
#    6972             with np.errstate(all="ignore"):
# -> 6973                 bm = self._mgr.apply(array_op, right=right)
#    6974             return self._constructor(bm)
#    6975
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     300             try:
#     301                 if callable(f):
# --> 302                     applied = b.apply(f, **kwargs)
#     303                 else:
#     304                     applied = getattr(b, f)(**kwargs)
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     400         one
#     401         """
# --> 402         result = func(self.values, **kwargs)
#     403
#     404         return self._split_op_result(result)
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     267     ):
#     268         # Call the method on lvalues
# --> 269         res_values = op(lvalues, rvalues)
#     270
#     271     elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/arraylike.py in __ge__(self, other)
#      58     @unpack_zerodim_and_defer("__ge__")
#      59     def __ge__(self, other):
# ---> 60         return self._cmp_method(other, operator.ge)
#      61
#      62     # -------------------------------------------------------------
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py in _cmp_method(self, other, op)
#    1008             other = self._validate_comparison_value(other)
#    1009         except InvalidComparison:
# -> 1010             return invalid_comparison(self, other, op)
#    1011
#    1012         dtype = getattr(other, "dtype", None)
#
# /opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/ops/invalid.py in invalid_comparison(left, right, op)
#      32     else:
#      33         typ = type(right).__name__
# ---> 34         raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      35     return res_values
#      36
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and int

# %%
 # What explains such large inv?
compa[compa.inv<10].inv.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Is Asset Growth Investment?
#
# * See Cooper, Gulen, Schill, JF (2008);
# * What is asset growth capturing other than investment?
#     * Mergers;
#     * Issuance;
#     * Spin-offs.
# * Is it really investments that forecast future stock returns?

# %%
# A more traditional measure of investment: CAPX
compa['inv_capx'] = compa['capx']/compa['at_lag']
filter_inv_capx = (compa['capx']<=0)|(compa['at_lag']<=0)|(compa.fdiff>1)
compa.loc[filter_inv_capx,'inv_capx']=np.nan

# %%
# Difference for Apple
compa.loc[(compa.gvkey=='001690')&
          (compa.fyear>=1985),['fyear','inv','inv_capx']
         ].set_index(['fyear']).plot(title="Apple's Investment")
# Out:
# <AxesSubplot:title={'center':"Apple's Investment"}, xlabel='fyear'>

# %%
compa.loc[(compa.gvkey=='001690')&
          (compa.fyear>=1985),
          ['fyear','inv_capx']
         ].set_index(['fyear']).plot(title="Apple's Investment")
# Out:
# <AxesSubplot:title={'center':"Apple's Investment"}, xlabel='fyear'>

# %% [markdown]
# # Save Output

# %%
compa.columns
# Out:
# Index(['gvkey', 'datadate', 'conm', 'tic', 'cusip', 'fyear', 'fyr', 'at',
#        'capx', 'ceq', 'cogs', 'csho', 'dlc', 'dlcch', 'dltt', 'dp', 'ib',
#        'itcb', 'lt', 'mib', 'naicsh', 'ni', 'prstkcc', 'pstk', 'pstkl',
#        'pstkrv', 're', 'revt', 'sale', 'seq', 'sich', 'txdb', 'txdi', 'txditc',
#        'wcapch', 'xint', 'xlr', 'xrd', 'xsga', 'se', 'ps', 'dt', 'be', 'cost',
#        'op', 'opbe', 'at_lag', 'inv', 'fdiff', 'inv_capx'],
#       dtype='object')

# %%
compa.to_pickle(path='compa_annual.pkl')
